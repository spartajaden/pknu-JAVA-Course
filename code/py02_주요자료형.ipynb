# %% [markdown]
# # 주요 자료형

# %% [markdown]
# # 리스트 자료형

# %%
#리스트 만들기
odd = [1,3,5,7,9]

# %%
#리스트 중요한점, 순서!!! index!!
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %%
s = "spring"
s[0]
a = [11,22,33,44,55]
print(a[0] + a[3])
# Out:
# 55

# %%
a = 'banana'
print(id(a))
b = a
print(id(b))
b = 'kiwi'
