# %%
# !pwd
# Out:
# /home/cjh/data

# %%
f = open("새파일이에요.txt","w")
f.close()

# %% [markdown]
# <div class="table-scroll-wrapper"><table>
# <thead>
# <tr>
# <th>파일열기모드</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>r</td>
# <td>읽기 모드: 파일을 읽기만 할 때 사용한다.</td>
# </tr>
# <tr>
# <td>w</td>
# <td>쓰기 모드: 파일에 내용을 쓸 때 사용한다.</td>
# </tr>
# <tr>
# <td>a</td>
# <td>추가 모드: 파일의 마지막에 새로운 내용을 추가할 때 사용한다.</td>
# </tr>
# </tbody>
# </table></div>

# %%
# 리눅스에서
f = open("/home/cjh/test.txt","w")
f.close()

# %%
f = open("새파일이에요.txt","w")

for i in range(0, 20, 2):
    f.write(str(i)+"\n")
f.close()

# %%
import requests as req

f = open("즐겨찾기종목.txt","a")
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text
code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)
    result = "종목:" + ori1 + "\n" + "가격:" + ori2 + "\n"
    f.write(result)
    
for x in code:
    finance(x)
f.close()
# Out:
# 종목: 삼성전자
# 가격: 178,400
# 종목: 기아
# 가격: 164,700
# 종목: 현대차
# 가격: 504,000
# 종목: 한화에어로스페이스
# 가격: 1,127,000
# 종목: 셀트리온
# 가격: 238,500

# %% [markdown]
# ## 파일읽어오기

# %%
# readline 함수 이용하기

# %%
# 응용 3(비트코인 시세)
import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
btc = res[29:34]
won = str(int(btc)*1450)
print((( won[-12:-8]+ "억") if won[-12:-8] else ""), won[-8:-4]+ '만',won[-4:]+ '원')
# Out:
#  9750만 9600원

# %%
# 파이썬의 파일 쓰기 기능을 이용하기
# 파일 쓰기 기능을 이용하여
# 로또 번호 중복없는 6개의 번호로 차례로 구성된
# 결과를 10가지로 추천하여
# "로또추천.txt" 라는 파일로 남기라.

import random
import os

# 파일 저장 위치 확인용 (선택사항)
print("파일 저장 위치:", os.getcwd())

with open("로또추천.txt", "w", encoding="utf-8") as f:
    f.write("로또 추천 번호 10세트\n\n")

    for game in range(1, 11):
        # 1~45 중 중복없는 6개 자동 생성
        lotto = random.sample(range(1, 46), 6)

        lotto.sort()
        line = ", ".join(f"{n:02d}" for n in lotto)
        f.write(f"{game:2}번째 : {line}\n")

print("완료! -> 로또추천.txt 생성됨")
# Out:
# 파일 저장 위치: /home/cjh/data
# 완료! -> 로또추천.txt 생성됨

# %%
import requests as req

f = open("즐겨찾기종목.txt","a")
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text
code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)
    result = "종목:" + ori1 + "\n" + "가격:" + ori2 + "\n"
    f.write(result)
    
for x in code:
    finance(x)
f.close()
# Out:
# 종목: 삼성전자
# 가격: 178,600
# 종목: 기아
# 가격: 166,300
# 종목: 현대차
# 가격: 506,000
# 종목: 한화에어로스페이스
# 가격: 1,131,000
# 종목: 셀트리온
# 가격: 238,500

# %%
f = open("./즐겨찾기종목.txt","r")
print(f)
f.close()
# Out:
# <_io.TextIOWrapper name='./즐겨찾기종목.txt' mode='r' encoding='UTF-8'>

# %%
f = open("./즐겨찾기종목.txt","a")
f.write(f"종목:홍길동\n가격:9,999,999")
f.close()

# %% [markdown]
# # 1.3 With문 으로 읽고, 쓰기

# %%
with open("./즐겨찾기종목.txt","r") as f: 
    print(f.closed)
    print(f.read())
    print(f.closed)
print(f.closed)
# Out:
# False
# 종목:삼성전자
# 가격:178,400
# 종목:기아
# 가격:164,700
# 종목:현대차
# 가격:504,000
# 종목:한화에어로스페이스
# 가격:1,127,000
# 종목:셀트리온
# 가격:238,500
# 종목:삼성전자
# 가격:178,600
# 종목:기아
# 가격:166,300
# 종목:현대차
# 가격:506,000
# 종목:한화에어로스페이스
# 가격:1,131,000
# 종목:셀트리온
# 가격:238,500
# 종목:홍길동
# 가격:9,999,999
# False
# True

# %%
# for 문 블록의 예  
for i in range(3):
    loop_var = "반복문 안의 변수"

# %% [markdown]
# # 프로그램의 입출력

# %%
import sys
args = sys.argv
for i in args:
    print(i)
# Out:
# /home/cjh/venv/lib/python3.12/site-packages/ipykernel_launcher.py
# -f
# /home/cjh/.local/share/jupyter/runtime/kernel-3c47c94e-0be4-4529-b268-83a11f430456.json
