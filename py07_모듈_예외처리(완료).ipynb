# %% [markdown]
# # 1. 응용하기

# %% [markdown]
# # 1.1 모듈

# %% [markdown]
# ## 1.1.1 if __name__=="__main__": 의미

# %%
import mod1 as m1
# Out:
# mod1
# 5
# 2

# %%
# !python3 mod1.py
# Out:
# __main__
# 5
# 2

# %%
print(m1.add(3, 4))
print(m1.add(8, 4))
print(m1.sub(3, 4))
print(m1.sub(9, 3))
# Out:
# 7
# 12
# -1
# 6

# %%
from mod1 import add , sub
print(add(55,13))
print(sub(55,13))
# Out:
# 68
# 42

# %%
m1.__name__
# Out:
# 'mod1'

# %% [markdown]
# ## 1.1.2 클래스나 변수 등을 포함한 모듈

# %%
import mod2
a = mod2.Math()
print(mod2.PI)
print(a.solv(10))
# Out:
# 3.141592
# 314.1592

# %%
from mod2 import Math,PI
a = Math()
print(PI)
print(a.solv(10))
# Out:
# 3.141592
# 314.1592

# %% [markdown]
# ## 1.1.3 다른 디렉터리에 있는 모듈을 불러오는 방법

# %%
# %%sh
# mkdir ./mymod
# mv mod2.py ./mymod/mymod2.py # mv 무브지만 이름변경도

# %%
import mymod2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import mymod2
#
# ModuleNotFoundError: No module named 'mymod2'

# %% [markdown]
# ![스크린샷 2026-02-19 104540.png](attachment:789d454e-7b47-4a6f-a73f-8b62877ecd61.png)

# %%
import sys
# !pwd # /home/cjh/data
# sys.path에 mymod2가 위치한 절대경로를 추가함.
sys.path.append("/home/cjh/data/mymod/")

# %%
sys.path
# Out:
# ['/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/home/cjh/venv/lib/python3.12/site-packages',
#  '/home/cjh/data/mymod/',
#  '/home/cjh/data/mymod/']

# %%
# PYTHONPATH 환경 변수 등 등록 하여 사용할 수 있다.

# %% [markdown]
# ## 1.1.4 !python3 -V

# %% [markdown]
# # 패키지

# %%
# %%sh
# mkdir game
# mkdir game/sound
# mkdir game/graphic
# mkdir game/play
# Out:
# mkdir: cannot create directory ‘game’: File exists
# mkdir: cannot create directory ‘game/sound’: File exists
# mkdir: cannot create directory ‘game/graphic’: File exists
# mkdir: cannot create directory ‘game/play’: File exists
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 get_ipython().run_cell_magic('sh', '', 'mkdir game\nmkdir game/sound\nmkdir game/graphic\nmkdir game/play\n')
#
# File ~/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
# ...

# %%
import os
os.makedirs("game/sound", exist_ok=True)
os.makedirs("game/graphic", exist_ok=True)
os.makedirs("game/play", exist_ok=True)

# %%
# %%sh
# echo "" > /home/cjh/data/game/__init__.py
# echo "" > /home/cjh/data/game/sound/__init__.py
# echo "" > /home/cjh/data/game/graphic/__init__.py
# echo "" > /home/cjh/data/game/play/__init__.py

# %%
# %%sh
# echo "def echo_test():\n\tprint('echo')" > /home/cjh/data/game/sound/echo.py
# echo "def echo_test():\n\tprint('echo')" > /home/cjh/data/game/graphic/render.py

# %% [markdown]
# # 1.2.1 패키지 안의 함수 실행하기

# %%
'''1'''
# import game.sound.echo
# game.sound.echo.echo_test()
'''2'''
# import game.sound.echo as ec
# ec.echo_test()
'''3'''
# from game.sound import echo
# echo.echo_test()
'''4'''
from game.sound.echo import echo_test
echo_test()
# Out:
# echo

# %%
f = open("/home/cjh/data/game/__init__.py","w")
st='''VERSION = 4.5

def print_version_info():
    print(f"The version of this game is {VERSION}. ")
'''

f.write(st)
f.close()

# %%
import game
print(game.VERSION)
game.print_version_info()
# Out:
# 4.5
# The version of this game is 4.5.

# %% [markdown]
# ## 패키지 내 모듈을 미리

# %%
st='''from.graphic.render import render_test

VERSION = 4.6

def print_version_info():
    print(f"The version of this game is {VERSION}.")
'''
with open("/home/cjh/data/game/__init__.py","w") as f:
    f.write(st)

# %%
import game
game.render_test()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import game
#       2 game.render_test()
#
# File ~/data/game/__init__.py:1
# ----> 1 from.graphic.render import render_test
#       3 VERSION = 4.6
#       5 def print_version_info():
#
# File ~/data/game/graphic/render.py:1
# ----> 1 from .graphic.render import echo_test
#       2 # from ..sound.echo import echo_test
#       3 def render_test():
#
# ModuleNotFoundError: No module named 'game.graphic.graphic'

# %% [markdown]
# ### 패키지 초기화

# %%
st='''from .graphic.render import render_test

VERSION = 4.7

def print_version_info():
    print(f"The version of this game is {VERSION}.")

print("Initializing game ...")
'''
with open("/home/cjh/data/game/__init__.py","w") as f:
    f.write(st)

# %%
import game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import game
#
# File ~/data/game/__init__.py:1
# ----> 1 from .graphic.render import render_test
#       3 VERSION = 4.7
#       5 def print_version_info():
#
# File ~/data/game/graphic/render.py:1
# ----> 1 from .graphic.render import echo_test
#       2 # from ..sound.echo import echo_test
#       3 def render_test():
#
# ModuleNotFoundError: No module named 'game.graphic.graphic'

# %%
from game.graphic.render import render_test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from game.graphic.render import render_test
#
# File ~/data/game/graphic/render.py:1
# ----> 1 from .graphic.render import echo_test
#       2 # from ..sound.echo import echo_test
#       3 def render_test():
#
# ModuleNotFoundError: No module named 'game.graphic.graphic'

# %% [markdown]
# ## 1.2.4 all (*)

# %%
from game.sound import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from game.sound import *
#
# File ~/data/game/__init__.py:1
# ----> 1 from .graphic.render import render_test
#       3 VERSION = 4.7
#       5 def print_version_info():
#
# File ~/data/game/graphic/render.py:1
# ----> 1 from .graphic.render import echo_test
#       2 # from ..sound.echo import echo_test
#       3 def render_test():
#
# ModuleNotFoundError: No module named 'game.graphic.graphic'

# %%
with open("/home/cjh/data/game/sound/__init__.py","w") as f:
    f.write("__all__ = ['echo']")

# %%
echo.echo_test()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 echo.echo_test()
#
# NameError: name 'echo' is not defined

# %% [markdown]
# # 상대경로 패키지

# %%
st='''from .graphic.render import echo_test
# from ..sound.echo import echo_test
def render_test():
    print("render")
    echo_test()
'''
with open("/home/cjh/data/game/graphic/render.py","w") as f:
    f.write(st)

# %%
from game.graphic.render import render_test
render_test()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from game.graphic.render import render_test
#       2 render_test()
#
# File ~/data/game/graphic/render.py:1
# ----> 1 from .graphic.render import echo_test
#       2 # from ..sound.echo import echo_test
#       3 def render_test():
#
# ModuleNotFoundError: No module named 'game.graphic.graphic'

# %% [markdown]
# # 2. 예외 처리

# %% [markdown]
# ![스크린샷 2026-02-19 123815.png](attachment:4454b6dc-8287-4122-ab6d-6084b036dc39.png)

# %%
try: 
    4 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try: 
    4 / 0
except ZeroDivisionError as e:
    print(e)
finally:
    print("응?")
# Out:
# division by zero
# 응?

# %%
try:
    f = open('foo.txt', 'w')
    # 무언가를 수행한다.

finally:
    f.close() # 중간에 오류가 발생하더라도 무조건 실행된다.
    print("파일을 열고 닫았습니다.")
# Out:
# 파일을 열고 닫았습니다.

# %%
# 먼저 만나는 오류를 출력
try:
    a = [1,2]
    print(a[3])
    4/0
    print("나는 멋져")
except ZeroDivisionError as e:
    print("0으로 나눌 수 없습니다.", e)
except IndexError as e:
    print("인덱싱 할 수 없습니다.", e)
# Out:
# 인덱싱 할 수 없습니다. list index out of range

# %%
# 먼저 만나는 오류를 출력
try:
    age = int(input('나이를 입력하세요: '))
except:
        print('미성년자는 출입금지입니다.')
else:
    try:
        if age <= 18:
            print('미성년자는 출입금지입니다.')
        else:
            print('환영합니다.')
    except:
        print("프로그램 점검요망.")
# Out:
# 나이를 입력하세요:  12
# 미성년자는 출입금지입니다.

# %%
# 오류 회피하기
students = ['김철수', '이영희', '박민수', '최유진']

for (i, student) in enumerate(students, 1):
    try:
        with open(f"{student}_성적.txt",'r') as f:
            score = f.read()
            print(f"{student}의 성적: {score}")
    except:
            print(f"{student}의 성적 파일이 없습니다. 건너뜁니다.")
            continue
# Out:
# 김철수의 성적 파일이 없습니다. 건너뜁니다.
# 이영희의 성적 파일이 없습니다. 건너뜁니다.
# 박민수의 성적 파일이 없습니다. 건너뜁니다.
# 최유진의 성적 파일이 없습니다. 건너뜁니다.

# %%
class Bird:
    def fly(self):
        # print("난다날어~! 나는누구 여긴어디~")
        # raise NotImplementedError
        raise "정의해주세요."

# %%
a = Bird()
a.fly()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 a = Bird()
# ----> 2 a.fly()
#
# Cell In[28], line 5, in Bird.fly(self)
#       2 def fly(self):
#       3     # print("난다날어~! 나는누구 여긴어디~")
#       4     # raise NotImplementedError
# ----> 5     raise "정의해주세요."
#
# TypeError: exceptions must derive from BaseException

# %%
class Eagle(Bird):
    def fly(self):
        print("난 진짜 난다!")

# %%
e = Eagle()
e.fly()
# Out:
# 난 진짜 난다!

# %%
class MyError(Exception):
    def __str__(self): #프린트 전용 구축
        return "나는 바보가 아냐! 코훌쩍..."

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError as e:
    print(e)
# Out:
# 천사
