# %% [markdown]
# # 1.1 함수기본

# %% [markdown]
# ![스크린샷 2026-02-11 135210.png](attachment:8ffe4d83-25e0-4685-91b3-bba98e024256.png)

# %%
def add():
    print("더했습니다.")

# %%
# 일급 객체
def add2():
    return "더했어요."

# %%
type(add())
# Out:
# 더했습니다.
# NoneType

# %%
type(add2())
# Out:
# str

# %%
st = add()
print(st)
# Out:
# 더했습니다.
# None

# %%
a = 13
def add(a):
    print(a)

# %%
# 일급객체
def add2():
    return "더했어요."

# %%
# 매개변수
def add( a, b):
    return( a + b)

# %%
# return 의 특징 , 함수종료, 리턴값은 오직하나
def return_test():
    '''
    이것은 리턴함수를 테스트 하는 함수 입니다.
    '''
    print("리턴전 입니다.")
    return
    print("리턴후 입니다.")
return_test()
# Out:
# 리턴전 입니다.

# %%
dir(return_test.__doc__)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
def tt():
    for n in range(10):
        print(n, end = " ")
        if n == 3: return

# %%
tt()
# Out:
# 0 1 2 3 4 5 6

# %%
def intro(name):
    print(f" {name}님 안녕하세요.")

# %%
intro("홍길동")
intro("슈퍼맨")
intro("이순신")
# Out:
#  홍길동님 안녕하세요.
#  슈퍼맨님 안녕하세요.
#  이순신님 안녕하세요.

# %%
def add( a, b):
    c = a + b
    return c
def mul( a, b):
    c = a * b
    return c

# %%
# 매개변수에 입력받을 인자의 깊이 모자랄때
# add(10)

# %% [markdown]
# ![스크린샷 2026-02-11 122534.png](attachment:8df96129-8fbe-48f4-8109-461715442432.png)

# %%
result = add(30, 20) + mul(30, 20)
print(result)
# Out:
# 650

# %%
def add_many(*args):
    result = 0
    for i in args:
        result += i
    return result

# %%
add_many(11,22,33,44)
# Out:
# 110

# %% [markdown]
# # 여러 개의 입력값을 받는 함수 만들기

# %%
def add_mul(choice, *args): 
    if choice == "add":   # 매개변수 choice에 "add"를 입력받았을 때
        result = 0 
        for i in args: 
            result = result + i 
    elif choice == "mul":   # 매개변수 choice에 "mul"을 입력받았을 때
        result = 1 
        for i in args: 
            result = result * i 
    return result

# %%
def add_mul(*args): 
    if choice == "add":   # 매개변수 choice에 "add"를 입력받았을 때
        result = 0 
        for i in args: 
            result = result + i 
    elif choice == "mul":   # 매개변수 choice에 "mul"을 입력받았을 때
        result = 1 
        for i in args: 
            result = result * i 
    return result

# %%
result = add_mul('add', 1,2,3,4,5)
print(result)
result = add_mul('mul', 1,2,3,4,5)
print(result)
# Out:
# 15
# 120

# %% [markdown]
# # 1.3 키워드 매개변수, kwargs

# %%
def print_test(*args):
    print(args,type(args))
print_test(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5) <class 'tuple'>

# %%
def print_kwargs(**kwargs):
    print(kwargs, type(kwargs))
print_kwargs(name='foo', age=3)
# Out:
# {'name': 'foo', 'age': 3} <class 'dict'>

# %% [markdown]
# # 1.4 함수의 반환값은 언제나 하나이다

# %%
def add_and_mul(a,b):
    # return a+b, a*b
    # return [a+b, a*b]
    return {a+b : a*b}

# %%
value = add_and_mul(3,5)
print(value,type(value))
# Out:
# (8, 15) <class 'tuple'>

# %% [markdown]
# # 매개변수에 초깃값 미리 설정하기 *

# %%
# 매개변수에 초깃값 미리 설정은 함수를 생성할 때 만든다.
def say_myself(name, age, man=True): 
    print("나의 이름은 %s 입니다." % name) 
    print("나이는 %d살입니다." % age) 
    if man: 
        print("남자입니다.")
    else: 
        print("여자입니다.")
say_myself("홍길동",22)
say_myself("박서방",23,man=True)
say_myself("향단이",24,man=False)
# Out:
# 나의 이름은 홍길동 입니다.
# 나이는 22살입니다.
# 남자입니다.
# 나의 이름은 박서방 입니다.
# 나이는 23살입니다.
# 남자입니다.
# 나의 이름은 향단이 입니다.
# 나이는 24살입니다.
# 여자입니다.

# %%
# default1.py
def say_myself(name, man=True, age): 
    print("나의 이름은 %s 입니다." % name) 
    print("나이는 %d살입니다." % age) 
    if man: 
        print("남자입니다.")
    else: 
        print("여자입니다.")
# Out:
#   Cell In[16], line 2
#     def say_myself(name, man=True, age):
#                                    ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# - 매개변수 초기화는 마지막에 둬야한다. 그뒤에 일반 매개변수가 오면 안된다.
#
#  ![스크린샷_11-2-2026_141145_localhost.jpeg](attachment:9e6c1007-fec0-4dfd-8b89-3763820e8e95.jpeg)

# %% [markdown]
# # 변수의 효력범위 *

# %%
# 함수 안에서 사용하는 매개변수는 함수 밖의 변수 이름과는 전혀 상관없다.
a = 1
def vartest(a):
    a = a +1
vartest(a)
print(a)
# Out:
# 1

# %%
def vartest(a):
    a = a +1
vartest(3)
print(a)
# Out:
# 1

# %%
# vartest_return.py
a = 1
def vartest(a):
    a = a +1
    return a
    
a = vartest(a)
print(a)
# Out:
# 2

# %%
# vartest_return.py
통장 = 1
def 치트():
    global 통장
    통장 = 통장 +1

print(통장)
치트()
print(통장)
# Out:
# 1
# 2

# %%
box = []
name = '홍길동'
def tt(name):
    box.append(name)
tt('슈퍼맨')
print(box)
# Out:
# ['슈퍼맨']

# %% [markdown]
# # 1.7. lambda 예약어 *

# %%
add = lambda a, b : a + b
result = add(11,22)
print(result)
# Out:
# 33

# %%
# 한줄짜리 익명함수
print((lambda x: x**3)(2))
# Out:
# 8

# %%
# lambda 응용
students = [("철수", 100), ("영희", 85), ("민수", 95)]
ss = sorted(students, key = lambda x: x[1] ,reverse=True)
print(ss)
# Out:
# [('철수', 100), ('민수', 95), ('영희', 85)]

# %%
# json 파싱하여 lambda로 키를 설정하여 가져오기
import requests as req
url = "https://jsonplaceholder.typicode.com/todos"
result = req.get(url).json()

# print("1. id의 번호를 기준으로 내림차순으로 정렬하라.")
fin = sorted(result, key= lambda x : x['id'] , reverse= True)
print(fin)

# print("2. completed 가 True 된 내용만 전처리하라.")
print([n for n in fin if n['completed'] == True ])

# print("3. 리스트의 각요소 끝에 score 이름으로 키를 만들고 그 키의 값을 40~100까지의 임의 값으로 배정하여 fix 라는 변수에 등록하라.")
import random as fix
for fix in range(40,101):
    print(f" score")


# print("4. score 를 키로 내림차순으로 sorted 하라.(원본손상 x)")
# Out:
# [{'userId': 10, 'id': 200, 'title': 'ipsam aperiam voluptates qui', 'completed': False}, {'userId': 10, 'id': 199, 'title': 'numquam repellendus a magnam', 'completed': True}, {'userId': 10, 'id': 198, 'title': 'quis eius est sint explicabo', 'completed': True}, {'userId': 10, 'id': 197, 'title': 'dignissimos quo nobis earum saepe', 'completed': True}, {'userId': 10, 'id': 196, 'title': 'consequuntur aut ut fugit similique', 'completed': True}, {'userId': 10, 'id': 195, 'title': 'rerum ex veniam mollitia voluptatibus pariatur', 'completed': True}, {'userId': 10, 'id': 194, 'title': 'sed ut vero sit molestiae', 'completed': False}, {'userId': 10, 'id': 193, 'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a', 'completed': True}, {'userId': 10, 'id': 192, 'title': 'ut quas possimus exercitationem sint voluptates', 'completed': False}, {'userId': 10, 'id': 191, 'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur', 'completed': True}, {'us
# ...

# %%
import requests as req
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text

code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)

for x in code:
    finance(x)
# Out:
# 종목: 삼성전자
# 가격: 167,800
# 종목: 기아
# 가격: 161,800
# 종목: 현대차
# 가격: 509,000
# 종목: 한화에어로스페이스
# 가격: 1,130,000
# 종목: 셀트리온
# 가격: 239,500

# %%
import requests as req
import matplotlib.pyplot as plt
url = "https://finance.naver.com/sise/sise_market_sum.naver"
ori = req.get(url).text

code = ['005930','000270','005380','012450','068270']

def finance(code = '005930'):
    start_title = ori.find(f'<a href="/item/main.naver?code={code}" class="tltle">')
    ori1 = ori[start_title : start_title + 70].replace(f'<a href="/item/main.naver?code={code}" class="tltle">','').replace('</a></td>','').replace('</a></td','').replace('\n','').strip()
    ori2 = ori[start_title + 70 : start_title + 105].replace('<td class="number">','').replace('</td>','').replace('>','').strip()
    print("종목:",ori1)
    print("가격:",ori2)
	
for x in code:
    finance(x)
	
color = ["skyblue", "orange", "skyblue", "orange", "skyblue"]
ori2 = []
values = []

if not values:
    print("\n그래프를 그릴 데이터가 없습니다. (파싱 실패)")
else:
    plt.figure(figsize=(9, 5.5))
    
    # x축을 종목명으로 (원본 코드의 x는 code 리스트라서 종목 코드만 나옴 → 보기 안 좋음)
    plt.bar(ori1 if ori1 else code, values, color=color[:len(values)])
    
    # 막대 위에 가격 표시 (옵션)
    for ori1, ori2 in enumerate(values):
        plt.text(ori1, ori2 + max(values)*0.008 if values else 0,
                 f'{ori2:,}', ha='center', va='bottom', fontsize=10)
        
plt.bar(x, ori2, values, color=color)
plt.title("주요 종목 현재가")
plt.xlabel("종목코드")
plt.ylabel("가격 (원)")
plt.grid(axis='y', alpha=0.3)
plt.show(block=True)
# Out:
# 종목: 삼성전자
# 가격: 174,250
# 종목: 기아
# 가격: 162,800
# 종목: 현대차
# 가격: 504,500
# 종목: 한화에어로스페이스
# 가격: 1,123,000
# 종목: 셀트리온
# 가격: 233,500
#
# 그래프를 그릴 데이터가 없습니다. (파싱 실패)
